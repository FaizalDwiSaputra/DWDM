# %%
import pandas as pd

# %%
test_data = pd.read_csv("test.csv")
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test_data.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
print("Jumlah Kolom data Test :", len(test_data))
# Out:
# Jumlah Kolom data Test : 418

# %%
gender = test_data["Sex"] == 'male'
test_data.loc[gender]
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0            892       3              Kelly, Mr. James  male  34.5      0
# 2            894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3            895       3              Wirz, Mr. Albert  male  27.0      0
# 5            897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7            899       2  Caldwell, Mr. Albert Francis  male  26.0      1
# ..           ...     ...                           ...   ...   ...    ...
# 407         1299       1    Widener, Mr. George Dunton  male  50.0      1
# 413         1305       3            Spector, Mr. Woolf  male   NaN      0
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   NaN      0
# 417         1309       3      Peter, Master. Michael J  male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# ...

# %%
gender = test_data['Sex'] == 'female'
name = test_data['Name'].str.contains("james", case=False)
test_data.loc[gender & name]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 362         1254       2       Ware, Mrs. John James (Florence Louise Long)
# 391         1283       1     Lines, Mrs. Ernest H (Elizabeth Lindsey James)
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 1    female  47.0      1      0    363272    7.0000          NaN        S
# 343  female  58.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 362  female  31.0      0      0  CA 31352   21.0000          NaN        S
# 391  female  51.0      0      1  PC 17592   39.4000          D28        S

# %%
gender = test_data['Sex'] == 'female'
name = test_data['Name'].str.contains("james", case=False)
gender2 = test_data['Sex'] == 'male'
name2 = test_data['Name'].str.contains("samuel", case=False)
test_data.loc[gender & name | gender2 & name2]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 9            901       3                            Davies, Mr. John Samuel
# 110         1002       2                           Stanton, Mr. Samuel Ward
# 229         1121       2                 Hocking, Mr. Samuel James Metcalfe
# 257         1149       3                              Niklasson, Mr. Samuel
# 320         1212       3                        Andersson, Mr. Johan Samuel
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 353         1245       2                                 Herman, Mr. Samuel
# 362         1254       2       Ware, Mrs. John James (Florence Louise Long)
# 391         1283       1     Lines, Mrs. Ernest H (Elizabeth Lindsey James)
#
#         Sex   Age  SibSp  Parch     Ticket      Fare        Cabin Embarked
# ...

# %%
gender = test_data['Sex'] == 'female' & 'male'
name = test_data['Name'].str.contains("james" & "samuel", case=False)
test_data.loc[gender & name]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gender = test_data['Sex'] == 'female' & 'male'
#       2 name = test_data['Name'].str.contains("james" & "samuel", case=False)
#       3 test_data.loc[gender & name]
#
# NameError: name 'test_data' is not defined
